# %% [markdown]
# <a href="https://colab.research.google.com/github/xFlodz/ismp/blob/main/%D0%A3%D0%9F%D0%98%D0%A1%20%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5%20%E2%84%961%20%D0%9E%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5%20%D0%BA%D0%BE%D0%BD%D1%86%D0%B5%D0%BF%D1%82%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D1%85%20%D0%BE%D1%81%D0%BD%D0%BE%D0%B2%20%D0%B4%D0%B8%D0%BF%D0%BB%D0%BE%D0%BC%D0%BD%D0%BE%D0%B3%D0%BE%20%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82%D0%B0%20%D0%B2%20%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D0%B8%20%D0%B8%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D1%85%20%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание №1. Определение концептуальных основ дипломного проекта в области информационных систем**

# %% [markdown]
# В рамках дисциплины "Управление проектами информационных систем" представьте развернутое концептуальное обоснование вашего проекта, ответив на следующие вопросы:

# %% [markdown]
# #### **1. Обоснование необходимости разработки**

# %% [markdown]
# Для кого предназначено разрабатываемое Вами решение и какие потребности целевой аудитории оно призвано удовлетворить?

# %% [markdown]
# *Обоснуйте актуальность решаемой проблемы для конкретных заинтересованных сторон.*

# %% [markdown]
# В современных реалиях количество источников пространственных данных растет с геометрической прогрессией. Все больше используется всевозможных датчиков и трекеров для передачи информации о местоположении того или иного устройства(телефоны, дроны, транспортные средства, даже роботы курьеры от Яндекса). Однако, при работе с такими масивами данных могут возникнуть проблемы. На этапе рендеринга большого числа движущихся объектов могут возникнуть лаги, или проблемы при передаче данных, из-за чего возникнут задержки, что весьма критично если необходимо отображать данные в режиме реального времени.
#
# Таким образом, необходимо выявить методы и подходы, которые будут устойчиво переносить высокие нагрузки, определить оптимальный по производительности технологический стек, который будет способен минимизировать задержки при рендеренге и передаче данных в режиме реального времени.
#
# По большей части данное иследование для айти специалистов, которым необходимо отображать большие объемы данных, при этом не столкнуться с проблемой низкой производительности.

# %% [markdown]
# ---

# %% [markdown]
# #### **2. Ожидаемые результаты проекта**

# %% [markdown]
# Опишите конкретные результаты, которые планируется получить по завершении проекта. Какой программный продукт, методика или информационная система будет создан/создана в результате вашей работы?

# %% [markdown]
# В конечном итоге будет создана интерактивная карта на основе deck.gl, которая использует WebGL при рендеренге. На ней будут отображены большие объемы пространственных данных, преимущественно динамических (как старых из существующих датасетов(NYC taxi), так и потоковых подгружаемых из различных апи). Будет проведено исследование в котором будут описаны следующие принципы:
#
# 1) Выьор архитектуры обработки данных (В каком случае лямбда паттерн https://habr.com/ru/companies/otus/articles/766672/, а в каком Каппа https://habr.com/ru/companies/otus/articles/769350/)/n
# 2) ВЫбор стека (В каких случаях лучше та, или иная колоночная(или не колоночная) СУБД, обоснование выбора того или иного фреймворка и т.д)
# 3) Как и какие слои(https://deck.gl/docs/api-reference/layers) deck.gl влияют на производительность
#
# Для тестов будут применены метрики: количество FPS, время первой отрисовки, время перерисовки при изменении LOD, время передачи данных(при бинаризации и без нее), количество потребляемой памяти

# %% [markdown]
# ---

# %% [markdown]
# #### **3. Методология использования**

# %% [markdown]
# Каким образом предполагается практическое применение разрабатываемого решения? Опишите основные сценарии взаимодействия пользователей с разрабатываемым решением.

# %% [markdown]
# Тут я еще не полностью решил, но скорее всего будет что-то вроде бенчмарка, где можно выбрать примерное количество объектов, слой и какие-то другие настройки
#
# Пользователь сможет выбрать интересующие его настройки, взаимодействовать с картой(приблежать, двигать, отдалять) и будет видеть метрики(фпс, время первой отрисовки, задержки между перерисовкой при изменении LOD, время передачи данных, потребление памяти)

# %% [markdown]
# ---

# %% [markdown]
# #### **4. Входные данные и их источники**

# %% [markdown]
# Какие типы данных будут использоваться в качестве входных данных для вашего решения? В каком формате они будут представлены и из каких источников планируется их получение?

# %% [markdown]
# В качестве основной нагрузки датасет об истории поездко такси NYCTaxi 2021/2022/2023 и т.д. В качестве потоковых данных это https://api.mta.info/#/landing - поезда, https://bustime.mta.info/ - автобусы, citibike - аренда велосипедов.
#
# Возможны еще дополнительные источники

# %% [markdown]
# ---

# %% [markdown]
# #### **5. Выходные данные и практическая значимость**

# %% [markdown]
# Какие результаты будет формировать Ваше решение на выходе?

# %% [markdown]
# В конечном итоге будет следущее:
#
# 1) Веб карта на deck.gl с реализацией методов пространственной агрегации, уровнями детализации LOD, а также отображением ключевых метрик производительности
#
# 2) Сравнительная таблица, в которой будут зафиксированы результаты тестов при различных конфигурациях
#
# 3) Набор рекомендаций при использования тех или иных технологий
#
# 4) Реализованные механизмы для имитации высокой нагрузки
#
# 5) Открытая кодовая база для всех желающих

# %% [markdown]
# ---

# %% [markdown]
# Опишите конкретно и без "воды" пользу (практическую ценность), которую заинтересованные стороны получат от использования этих результатов.

# %% [markdown]
# Практическая ценность заключается в том, что у айти специалистов будет база от которой они смогут отталкиваться во время принятия решений при проектировании информационных систем. Появятся объективные исследования с подтверждающими метриками на которые можно положиться при проектировании реальных проектов.

# %% [markdown]
# ---
